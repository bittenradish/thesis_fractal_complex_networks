# %%
import graph_tool.all as gt
g = gt.collection.ns["7th_graders"]

# %%
gt.graph_draw(g)
# Out:
# <VertexPropertyMap object with value type 'vector<double>', for Graph 0x7f8d1ae52da0, at 0x7f8e98e75480>
